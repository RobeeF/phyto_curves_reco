# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install fastparquet
# !sudo apt-get install libsnappy-dev
# !python3 -m pip install  python-snappy
# !python3 -m pip install pyarrow
# !pip install tensorflow-addons
# !pip install --upgrade numpy
# Out:
# Collecting fastparquet
#   Downloading fastparquet-0.7.1-cp37-cp37m-manylinux2010_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 5.0 MB/s
# Collecting thrift>=0.11.0
#   Downloading thrift-0.15.0.tar.gz (59 kB)
#      |████████████████████████████████| 59 kB 5.7 MB/s
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (1.19.5)
# Collecting cramjam>=2.3.0
#   Downloading cramjam-2.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 41.2 MB/s
# Collecting fsspec
#   Downloading fsspec-2021.10.1-py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 62.5 MB/s
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->fastparquet) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.0->fastparquet) (1.15.0)
# Building wheels for collected packages: thrift
#   Building wheel for thrift (setup.py) ... done
#   Created wheel for thrift: filename=thrift-0.15.0-cp37-cp37m-linux_x86_64.whl size=348183 sha256=064f4ed732ccaeb6a815e6676948e8e5dd64d36c96190a9bf221847b019f156b
#   Stored in directory: /root/.cache/pip/wheels/ba/1f/8e/e6fd36837eecf3d1f2b23f1729477e8e06558d8d60b7093f51
# Successfully built thrift
# Installing collected packages: thrift, fsspec, cramjam, fastparquet
# Successfully installed cramjam-2.4.0 fastparquet-0.7.1 fsspec-2021.10.1 thrift-0.15.0
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   libsnappy-dev
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 27.2 kB of archives.
# After this operation, 108 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsnappy-dev amd64 1.1.7-1 [27.2 kB]
# Fetched 27.2 kB in 0s (96.4 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libsnappy-dev:amd64.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../libsnappy-dev_1.1.7-1_amd64.deb ...
# Unpacking libsnappy-dev:amd64 (1.1.7-1) ...
# Setting up libsnappy-dev:amd64 (1.1.7-1) ...
# Collecting python-snappy
#   Downloading python_snappy-0.6.0-cp37-cp37m-manylinux2010_x86_64.whl (55 kB)
#      |████████████████████████████████| 55 kB 1.7 MB/s
# Installing collected packages: python-snappy
# Successfully installed python-snappy-0.6.0
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (3.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from pyarrow) (1.19.5)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.14.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.0 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.14.0
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)
# Collecting numpy
#   Downloading numpy-1.21.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 116 kB/s
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.0 requires numpy~=1.19.2, but you have numpy 1.21.3 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.21.3

# %%
import os
os.chdir('/content/gdrive/My Drive/phyto_curves_reco')

import re
import pandas as pd
from pred_functions import predict
from keras.models import load_model
from time import time

from tensorflow_addons.optimizers import RectifiedAdam, Lookahead
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# Model and nomenclature loading
cnn = load_model('/content/gdrive/My Drive/Models/SSLAMM/cnn_small')

# %%
os.chdir('/content/gdrive/My Drive/data/SSLAMM/')

# %%
tn = pd.read_csv('L2/Pulse/train_test_nomenclature.csv')
tn.columns = ['name', 'id']

# Define where to look the data at and where to store preds
export_folder = "full_data/"
export_files = os.listdir(export_folder)

pulse_regex = "_Pulse" 
files_to_pred = [file for file in export_files if re.search(pulse_regex, file) and re.search('.parq', file)] # The files containing the data to predict

# %%
files_to_pred.sort()
files_to_pred = files_to_pred[1550:1580]

# %%
# Create a log file in the destination folder: list of the already predicted files
preds_store_folder = "/content/gdrive/My Drive/Results/SSLAMM/Preds1"  # Where to store the predictions
log_path = preds_store_folder + "/pred_logs.txt" # Register where write the already predicted files

if not(os.path.isfile(log_path)):
    open(log_path, 'w+').close()

# %%
start_time = time()
nb_files_to_pred = len(files_to_pred)
print(nb_files_to_pred)
# Out:
# 30

# %%
for idx, file in enumerate(files_to_pred):
    print('Currently predicting ' + file + ' ' + str(idx))
    path = export_folder + '/' + file
    is_already_pred = False
    
    # Check if file has already been predicted.
    with open(log_path, "r") as log_file:
        if file in log_file.read(): 
            is_already_pred = True
    
    if not(is_already_pred): # If not, perform the prediction
        # Predict the values
        predict(path, preds_store_folder,  cnn, tn,\
            is_ground_truth = False)

        # Write in the logs that this file is already predicted
        with open(log_path, "a") as log_file:
            log_file.write(file + '\n')

        step_time = time()
        average_pred_time = (step_time - start_time) / (idx + 1)
        remaining_time = average_pred_time * (nb_files_to_pred - idx - 1)
        print('Average per file pred time', average_pred_time, idx, 'files already predicted')
        print('Remaining time before end of pred', remaining_time)
          
    else:
        print(file, 'already predicted')
# Out:
# Currently predicting Labelled_Pulse6_2019-12-03 23h59.parq 0
# Average per file pred time 80.30089998245239 0 files already predicted
# Remaining time before end of pred 2328.7260994911194
# Currently predicting Labelled_Pulse6_2019-12-04 01h59.parq 1
# Average per file pred time 85.67184209823608 1 files already predicted
# Remaining time before end of pred 2398.8115787506104
# Currently predicting Labelled_Pulse6_2019-12-04 03h59.parq 2
# Average per file pred time 89.56807065010071 2 files already predicted
# Remaining time before end of pred 2418.337907552719
# Currently predicting Labelled_Pulse6_2019-12-04 05h59.parq 3
# Average per file pred time 96.17107313871384 3 files already predicted
# Remaining time before end of pred 2500.4479016065598
# Currently predicting Labelled_Pulse6_2019-12-04 13h43.parq 4
# Average per file pred time 111.0792637348175 4 files already predicted
# Remaining time before end of pred 2776.9815933704376
# Currently predicting Labelled_Pulse6_2019-12-04 13h54.parq 5
# Average per file pred time 95.08204845587413 5 files already predicted
# Remaining time before end of pred 2281.969162940979
# Currently predicting Labelled_Pulse6_2019-12-04 13h59.parq 6
# Average per file pred time 90.50280008997235 6 files already predicted
# Remaining time before end of pred 2081.564402069364
# Currently predicting Labelled_Pulse6_2019-12-04 15h59.parq 7
# Average per file pred time 90.38167557120323 7 files already predicted
# Remaining time before end of pred 1988.396862566471
# Currently predicting Labelled_Pulse6_2019-12-04 17h59.parq 8
# Average per file pred time 91.17778340975444 8 files already predicted
# Remaining time before end of pred 1914.7334516048431
# Currently predicting Labelled_Pulse6_2019-12-04 19h59.parq 9
# Average per file pred time 93.07165081501007 9 files already predicted
# Remaining time before end of pred 1861.4330163002014
# Currently predicting Labelled_Pulse6_2019-12-04 21h59.parq 10
# Average per file pred time 96.29842853546143 10 files already predicted
# Remaining time before end of pred 1829.670142173767
# Currently predicting Labelled_Pulse6_2019-12-04 23h59.parq 11
# Average per file pred time 100.11395192146301 11 files already predicted
# Remaining time before end of pred 1802.0511345863342
# Currently predicting Labelled_Pulse6_2019-12-05 01h59.parq 12
# Average per file pred time 103.85623029562143 12 files already predicted
# Remaining time before end of pred 1765.5559150255642
# Currently predicting Labelled_Pulse6_2019-12-05 03h59.parq 13
# Average per file pred time 107.08212571484702 13 files already predicted
# Remaining time before end of pred 1713.3140114375524
# Currently predicting Labelled_Pulse6_2019-12-05 05h59.parq 14
# Average per file pred time 110.15801723798116 14 files already predicted
# Remaining time before end of pred 1652.3702585697174
# Currently predicting Labelled_Pulse6_2019-12-05 07h59.parq 15
# Average per file pred time 113.86117930710316 15 files already predicted
# Remaining time before end of pred 1594.0565102994442
# Currently predicting Labelled_Pulse6_2019-12-05 09h59.parq 16
# Average per file pred time 118.9905354976654 16 files already predicted
# Remaining time before end of pred 1546.8769614696503
# Currently predicting Labelled_Pulse6_2019-12-05 11h59.parq 17
# Average per file pred time 122.21644843949213 17 files already predicted
# Remaining time before end of pred 1466.5973812739055
# Currently predicting Labelled_Pulse6_2019-12-05 13h59.parq 18
# Average per file pred time 125.05224190260235 18 files already predicted
# Remaining time before end of pred 1375.574660928626
# Currently predicting Labelled_Pulse6_2019-12-05 15h59.parq 19
# Average per file pred time 128.07891331911088 19 files already predicted
# Remaining time before end of pred 1280.7891331911087
# Currently predicting Labelled_Pulse6_2019-12-05 17h59.parq 20
# Labelled_Pulse6_2019-12-05 17h59.parq already predicted
# Currently predicting Labelled_Pulse6_2019-12-05 19h59.parq 21
# Labelled_Pulse6_2019-12-05 19h59.parq already predicted
# Currently predicting Labelled_Pulse6_2019-12-05 21h59.parq 22
# Labelled_Pulse6_2019-12-05 21h59.parq already predicted
# Currently predicting Labelled_Pulse6_2019-12-05 23h59.parq 23
# Labelled_Pulse6_2019-12-05 23h59.parq already predicted
# Currently predicting Labelled_Pulse6_2019-12-06 01h59.parq 24
# Average per file pred time 110.58729686737061 24 files already predicted
# Remaining time before end of pred 552.936484336853
# Currently predicting Labelled_Pulse6_2019-12-06 03h59.parq 25
# Labelled_Pulse6_2019-12-06 03h59.parq already predicted
# Currently predicting Labelled_Pulse6_2019-12-06 05h59.parq 26
# Labelled_Pulse6_2019-12-06 05h59.parq already predicted
# Currently predicting Labelled_Pulse6_2019-12-06 07h59.parq 27
# Labelled_Pulse6_2019-12-06 07h59.parq already predicted
# Currently predicting Labelled_Pulse6_2019-12-06 09h59.parq 28
# Labelled_Pulse6_2019-12-06 09h59.parq already predicted
# Currently predicting Labelled_Pulse6_2019-12-06 11h59.parq 29
# Average per file pred time 99.77621715863546 29 files already predicted
# Remaining time before end of pred 0.0
