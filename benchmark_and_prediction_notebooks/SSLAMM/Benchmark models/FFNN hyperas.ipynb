# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/My Drive/phyto_curves_reco
# Out:
# /content/gdrive/My Drive/phyto_curves_reco

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
tf.test.gpu_device_name()
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 13107192398797845485, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11345264640
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 2252913367856126302
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %%
! pip install hyperas
! pip install hyperopt
# !pip install tensorflow-addons

# %%
! python ffnn_hyperopt_categ_loss.py '../data/SSLAMM/L2/Listmodes/' '/content/gdrive/My Drive/Models/SSLAMM/'
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import sys
# except:
#     pass
#
# try:
#     import pickle
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform, normal
# except:
#     pass
#
# try:
#     from sklearn.preprocessing import StandardScaler
# except:
#     pass
#
# try:
#     from sklearn.metrics import confusion_matrix, precision_score, recall_score
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# except:
#     pass
#
# try:
#     from tensorflow_addons.optimizers import RectifiedAdam, Lookahead
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
# ...

# %%
#! python hyperOptimisationFFNN.py '../data/SSLAMM/L2/Listmodes/' 30 '/content/gdrive/My Drive/Models/SSLAMM/' 'FFNN' 'categorical_crossentropy' 120

# %%
#! python ffnn_hyperopt_cbf_loss.py

# %%
#! python ffnn_hyperopt_focal_loss.py
