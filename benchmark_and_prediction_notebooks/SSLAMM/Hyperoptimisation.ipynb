# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/phyto_curves_reco
# Out:
# /content/gdrive/My Drive/phyto_curves_reco

# %%
#! git clone https://github.com/RobeeF/phyto_curves_reco

# %%
! pip install hyperas
! pip install hyperopt
# !pip install tensorflow-addons

# %%
! python hyperOptimisation.py '../data/SSLAMM/L2/Pulse/' 30 '/content/gdrive/My Drive/Models/SSLAMM/' 'cnn_small' 'categorical_crossentropy' 120
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#
#
# Epoch 00010: val_loss did not improve from 0.04217
# Epoch 11/120
# 264/264 - 3s - loss: 0.0099 - accuracy: 0.9751 - val_loss: 0.0443 - val_accuracy: 0.9858
#
#
# Epoch 00011: val_loss did not improve from 0.04217
# Epoch 12/120
# 264/264 - 3s - loss: 0.0096 - accuracy: 0.9757 - val_loss: 0.0838 - val_accuracy: 0.9717
#
#
# Epoch 00012: val_loss did not improve from 0.04217
# Epoch 13/120
# 264/264 - 3s - loss: 0.0093 - accuracy: 0.9773 - val_loss: 0.0510 - val_accuracy: 0.9838
#
#
# Epoch 00013: val_loss did not improve from 0.04217
# Epoch 14/120
# 264/264 - 3s - loss: 0.0085 - accuracy: 0.9782 - val_loss: 0.0517 - val_accuracy: 0.9816
#
#
# Epoch 00014: val_loss did not improve from 0.04217
# Epoch 15/120
# 264/264 - 3s - loss: 0.0087 - accuracy: 0.9789 - val_loss: 0.0671 - val_accuracy: 0.9800
#
#
# Epoch 00015: val_loss did not improve from 0.04217
# Epoch 16/120
# ...

# %%
#! python hyperOptimisation.py '../data/SSLAMM/L2/Pulse/' 30 '/content/gdrive/My Drive/Models/SSLAMM/' 'cnn_HyperCB' 'Class_balanced' 80

# %%
#! python hyperOptimisation.py '../data/SSLAMM/L2/Pulse/' 30 '/content/gdrive/My Drive/Models/SSLAMM/' 'cnn_HyperCB' 'Focal_loss' 80
