# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/phyto_curves_reco
# Out:
# /content/gdrive/My Drive/phyto_curves_reco

# %%
#! git clone https://github.com/RobeeF/phyto_curves_reco

# %%
! pip install hyperas
! pip install hyperopt
# !pip install tensorflow-addons
# Out:
# ...
#      |████████████████████████████████| 1.1 MB 14.7 MB/s
# ...

# %%
! python hyperOptimisation.py '../data/SWINGS/L2/Pulse/' 30 '/content/gdrive/My Drive/Models/SWINGS/' 'dumb' 'categorical_crossentropy' 120
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import os
# except:
#     pass
#
# try:
#     import sys
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import pickle
# except:
#     pass
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     from sklearn.metrics import confusion_matrix, precision_score
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     from tensorflow_addons.optimizers import RectifiedAdam, Lookahead
# except:
#     pass
#
# try:
#     from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform, normal
# except:
#     pass
#
# try:
#     from losses import CB_loss, categorical_focal_loss
# except:
#     pass
#
# ...

# %%
#! python hyperoptCNN.py '../data/SWINGS/L2/Pulse/'

# %%
#! python hyperoptCNN.py '../data/SWINGS/L2/Pulse/'

# %%
! python hyperoptCNN.py '../data/SWINGS/L2/Pulse/' 30 '/content/gdrive/My Drive/Models/SWINGS/' 'cnn_realsmall' 'categorical_crossentropy' 120
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#
#
# Epoch 00009: val_loss did not improve from 0.28050
# Epoch 10/120
# 1789/1789 - 10s - loss: 0.0843 - accuracy: 0.7583 - val_loss: 0.2646 - val_accuracy: 0.9665
#
#
# Epoch 00010: val_loss improved from 0.28050 to 0.26462, saving model to /content/gdrive/My Drive/Models/SWINGS/weights_categorical_crossentropy_cnn_realsmall.hdf5
# Epoch 11/120
# 1789/1789 - 10s - loss: 0.0815 - accuracy: 0.7671 - val_loss: 0.3972 - val_accuracy: 0.9590
#
#
# Epoch 00011: val_loss did not improve from 0.26462
# Epoch 12/120
# 1789/1789 - 10s - loss: 0.0791 - accuracy: 0.7733 - val_loss: 0.2535 - val_accuracy: 0.9679
#
#
# Epoch 00012: val_loss improved from 0.26462 to 0.25346, saving model to /content/gdrive/My Drive/Models/SWINGS/weights_categorical_crossentropy_cnn_realsmall.hdf5
# Epoch 13/120
# 1789/1789 - 11s - loss: 0.0779 - accuracy: 0.7771 - val_loss: 0.2826 - val_accuracy: 0.9657
#
#
# ...

# %%
! python hyperOptimisation.py '../data/SWINGS/L2/Pulse/' 30 '/content/gdrive/My Drive/Models/SWINGS/' 'cnn_small_trainweights' 'categorical_crossentropy' 120
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import os
# except:
#     pass
#
# try:
#     import sys
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import pickle
# except:
#     pass
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     from sklearn.metrics import confusion_matrix, precision_score
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     from tensorflow_addons.optimizers import RectifiedAdam, Lookahead
# except:
#     pass
#
# try:
#     from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform, normal
# except:
#     pass
#
# try:
#     from losses import CB_loss, categorical_focal_loss
# except:
#     pass
#
# ...

# %%
! python hyperOptimisation.py '../data/SWINGS/L2/Pulse/' 30 '/content/gdrive/My Drive/Models/SWINGS/' 'cnn_HyperCB41' 'Class_balanced' 80
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import os
# except:
#     pass
#
# try:
#     import sys
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import pickle
# except:
#     pass
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     from collections import Counter
# except:
#     pass
#
# try:
#     from sklearn.metrics import confusion_matrix, precision_score
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     from tensorflow_addons.optimizers import RectifiedAdam, Lookahead
# except:
#     pass
#
# try:
#     from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform, normal
# except:
#     pass
#
# try:
# ...

# %%
#! python hyperOptimisation.py '../data/SWINGS/L2/Pulse/' 30 '/content/gdrive/My Drive/Models/SWINGS/' 'cnn_HyperCB41' 'Focal_loss' 80
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import os
# except:
#     pass
#
# try:
#     import sys
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import pickle
# except:
#     pass
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     from collections import Counter
# except:
#     pass
#
# try:
#     from sklearn.metrics import confusion_matrix, precision_score
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     from tensorflow_addons.optimizers import RectifiedAdam, Lookahead
# except:
#     pass
#
# try:
#     from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform, normal
# except:
#     pass
#
# try:
# ...
