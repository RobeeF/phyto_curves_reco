# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/phyto_curves_reco
# Out:
# /content/gdrive/My Drive/phyto_curves_reco

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
tf.test.gpu_device_name()
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 17564832394242076335]

# %%
! pip install hyperas
! pip install hyperopt
# !pip install tensorflow-addons
# Out:
# ...
#      |████████████████████████████████| 1.1 MB 4.4 MB/s
# ...

# %%
! python ffnn_hyperopt_categ_loss.py '../data/SWINGS/L2/Listmodes/' '/content/gdrive/My Drive/Models/SWINGS/'
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import sys
# except:
#     pass
#
# try:
#     import pickle
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform, normal
# except:
#     pass
#
# try:
#     from sklearn.preprocessing import StandardScaler
# except:
#     pass
#
# try:
#     from sklearn.metrics import confusion_matrix, precision_score, recall_score
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# except:
#     pass
#
# try:
#     from tensorflow_addons.optimizers import RectifiedAdam, Lookahead
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
# ...

# %%
#! python hyperOptimisationFFNN.py '../data/SWINGS/L2/Listmodes/' 30 '/content/gdrive/My Drive/Models/SWINGS/' 'FFNN' 'categorical_crossentropy' 120

# %%
#! python ffnn_hyperopt_cbf_loss.py

# %%
#! python ffnn_hyperopt_focal_loss.py
