# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install fastparquet
# Out:
# Requirement already satisfied: fastparquet in /usr/local/lib/python3.7/dist-packages (0.7.0)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (1.21.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (1.1.5)
# Requirement already satisfied: cramjam>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (2.3.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.7/dist-packages (from fastparquet) (2021.7.0)
# Requirement already satisfied: thrift>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (0.13.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->fastparquet) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->fastparquet) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.0->fastparquet) (1.15.0)

# %%
# !sudo apt-get install libsnappy-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsnappy-dev is already the newest version (1.1.7-1).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.

# %%
# !python3 -m pip install  python-snappy
# Out:
# Requirement already satisfied: python-snappy in /usr/local/lib/python3.7/dist-packages (0.6.0)

# %%
# !python3 -m pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (3.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from pyarrow) (1.21.1)

# %%
# !pip install --upgrade numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.1)

# %%
#!git clone https://github.com/RobeeF/phyto_curves_reco

# %%
import os

os.chdir('/content/gdrive/My Drive/phyto_curves_reco')

import re
import pandas as pd

from pred_functions import predict
from tensorflow.keras.models import load_model, model_from_json
from time import time
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
os.chdir('/content/gdrive/My Drive/')

# %%
# Model and nomenclature loading
cnn = load_model('/content/gdrive/My Drive/cnn_hyperopt_model_categ_best')

# %%
tn = pd.read_csv('/content/gdrive/My Drive/data/SWINGS/L1_retreated/75 percent_6 sets/train_test_nomenclature.csv')
tn.columns = ['Particle_class', 'label']

# Define where to look the data at and where to store preds
export_folder = "/content/gdrive/My Drive/data/SWINGS/Preds/To do/L1/Missing"
export_files = os.listdir(export_folder)

pulse_regex = "_Pulse" 
files_to_pred = [file for file in export_files if re.search(pulse_regex, file) and re.search('.parq', file)] # The files containing the data to predict
#files_to_pred = ['Labelled_Pulse5_2021-02-08 12h11.parq', 'Labelled_Pulse5_2021-02-08 14h11.parq', 'Labelled_Pulse5_2021-02-08 16h11.parq', 'Labelled_Pulse5_2021-02-09 16h11.parq', 'Labelled_Pulse5_2021-02-09 18h11.parq', 'Labelled_Pulse5_2021-02-09 20h11.parq','Labelled_Pulse5_2021-02-09 22h11.parq', 'Labelled_Pulse5_2021-02-10 00h11.parq', 'Labelled_Pulse5_2021-02-10 02h11.parq', 'Labelled_Pulse5_2021-02-10 04h11.parq']
print(files_to_pred)
# Out:
# ['Labelled_Pulse5_2021-02-22 02h11.parq', 'Labelled_Pulse5_2021-02-19 14h11.parq', 'Labelled_Pulse5_2021-03-04 00h11.parq', 'Labelled_Pulse5_2021-02-28 18h11.parq', 'Labelled_Pulse5_2021-02-11 04h11.parq', 'Labelled_Pulse5_2021-02-27 14h11.parq', 'Labelled_Pulse5_2021-02-03 00h11.parq', 'Labelled_Pulse5_2021-02-01 18h11.parq', 'Labelled_Pulse5_2021-02-20 10h11.parq', 'Labelled_Pulse5_2021-02-20 02h11.parq', 'Labelled_Pulse5_2021-01-15 20h11.parq', 'Labelled_Pulse5_2021-03-06 10h11.parq', 'Labelled_Pulse5_2021-02-10 06h11.parq', 'Labelled_Pulse5_2021-02-18 14h11.parq', 'Labelled_Pulse5_2021-01-27 22h11.parq', 'Labelled_Pulse5_2021-02-16 02h11.parq', 'Labelled_Pulse5_2021-02-03 12h11.parq', 'Labelled_Pulse5_2021-02-06 18h11.parq', 'Labelled_Pulse5_2021-03-05 18h11.parq', 'Labelled_Pulse5_2021-01-24 20h11.parq', 'Labelled_Pulse5_2021-01-14 14h11.parq', 'Labelled_Pulse5_2021-03-05 22h11.parq', 'Labelled_Pulse5_2021-01-29 22h11.parq', 'Labelled_Pulse5_2021-01-26 08h11.parq', 'Labelled_Pulse5_2021-01-25 16h11.parq', 'Labelled_Pulse5_2021-02-12 04h11.parq', 'Labelled_Pulse5_2021-02-08 06h11.parq', 'Labelled_Pulse5_2021-02-02 22h11.parq', 'Labelled_Pulse5_2021-02-27 06h11.parq', 'Labelled_Pulse5_2021-01-16 08h11.parq', 'Labelled_Pulse5_2021-03-03 02h11.parq', 'Labelled_Pulse5_2021-01-28 22h11.parq', 'Labelled_Pulse5_2021-02-11 06h11.parq', 'Labelled_Pulse5_2021-01-26 06h11.parq', 'Labelled_Pulse5_2021-03-02 14h11.parq', 'Labelled_Pulse5_2021-03-05 14h11.parq', 'Labelled_Pulse5_2021-03-01 16h11.parq', 'Labelled_Pulse5_2021-03-04 02h11.parq', 'Labelled_Pulse5_2021-01-17 08h11.parq', 'Labelled_Pulse5_2021-02-17 20h11.parq', 'Labelled_Pulse5_2021-01-17 20h11.parq', 'Labelled_Pulse5_2021-02-07 10h11.parq', 'Labelled_Pulse5_2021-01-14 02h11.parq', 'Labelled_Pulse5_2021-02-26 22h11.parq', 'Labelled_Pulse5_2021-01-26 22h11.parq', 'Labelled_Pulse5_2021-01-29 08h11.parq', 'Labelled_Pulse5_2021-02-17 00h11.parq', 'Labelled_Pulse5_2021-02-05 04h11.parq', 'Labelled_Pulse5_2021-01-24 00h11.parq', 'Labelled_Pulse5_2021-01-22 16h11.parq', 'Labelled_Pulse5_2021-01-19 10h11.parq', 'Labelled_Pulse5_2021-02-23 14h11.parq', 'Labelled_Pulse5_2021-02-23 00h11.parq', 'Labelled_Pulse5_2021-03-05 02h11.parq', 'Labelled_Pulse5_2021-02-03 14h11.parq', 'Labelled_Pulse5_2021-01-16 22h11.parq', 'Labelled_Pulse5_2021-03-04 16h11.parq', 'Labelled_Pulse5_2021-02-10 02h11.parq', 'Labelled_Pulse5_2021-02-05 14h11.parq', 'Labelled_Pulse5_2021-02-19 20h11.parq', 'Labelled_Pulse5_2021-01-18 12h11.parq', 'Labelled_Pulse5_2021-01-28 06h11.parq', 'Labelled_Pulse5_2021-02-12 14h11.parq', 'Labelled_Pulse5_2021-02-25 22h11.parq', 'Labelled_Pulse5_2021-01-27 06h11.parq', 'Labelled_Pulse5_2021-03-05 16h11.parq', 'Labelled_Pulse5_2021-03-04 18h11.parq', 'Labelled_Pulse5_2021-02-26 08h11.parq', 'Labelled_Pulse5_2021-03-03 16h11.parq', 'Labelled_Pulse5_2021-03-06 16h11.parq', 'Labelled_Pulse5_2021-01-21 14h11.parq', 'Labelled_Pulse5_2021-01-27 16h11.parq', 'Labelled_Pulse5_2021-01-28 04h11.parq', 'Labelled_Pulse5_2021-01-24 10h11.parq', 'Labelled_Pulse5_2021-02-26 00h11.parq', 'Labelled_Pulse5_2021-03-03 12h11.parq', 'Labelled_Pulse5_2021-01-26 14h11.parq', 'Labelled_Pulse5_2021-02-13 12h11.parq', 'Labelled_Pulse5_2021-02-22 22h11.parq', 'Labelled_Pulse5_2021-02-03 22h11.parq', 'Labelled_Pulse5_2021-03-04 20h11.parq', 'Labelled_Pulse5_2021-02-15 16h11.parq', 'Labelled_Pulse5_2021-01-23 04h11.parq', 'Labelled_Pulse5_2021-02-04 04h11.parq', 'Labelled_Pulse5_2021-01-16 12h11.parq', 'Labelled_Pulse5_2021-02-08 14h11.parq', 'Labelled_Pulse5_2021-02-25 02h11.parq', 'Labelled_Pulse5_2021-01-22 08h11.parq', 'Labelled_Pulse5_2021-02-24 00h11.parq', 'Labelled_Pulse5_2021-02-26 02h11.parq', 'Labelled_Pulse5_2021-02-21 16h11.parq', 'Labelled_Pulse5_2021-01-24 04h11.parq', 'Labelled_Pulse5_2021-02-14 02h11.parq', 'Labelled_Pulse5_2021-02-06 20h11.parq', 'Labelled_Pulse5_2021-01-25 02h11.parq', 'Labelled_Pulse5_2021-02-20 14h11.parq', 'Labelled_Pulse5_2021-02-25 00h11.parq', 'Labelled_Pulse5_2021- ...

# %%
files_to_pred = files_to_pred[(len(files_to_pred) // 2):]

# %%
# Create a log file in the destination folder: list of the already predicted files
preds_store_folder = "/content/gdrive/My Drive/data/SWINGS/Preds/Done/75 percent_6 sets/Missing"  # Where to store the predictions
log_path = preds_store_folder + "/pred_logs.txt" # Register where write the already predicted files

if not(os.path.isfile(log_path)):
    open(log_path, 'w+').close()

# %%
start_time = time()
nb_files_to_pred = len(files_to_pred)

# %%
for idx, file in enumerate(files_to_pred):
    print('Currently predicting ' + file + ' ' + str(idx))
    path = export_folder + '/' + file
    is_already_pred = False
    
    # Check if file has already been predicted
    with open(log_path, "r") as log_file:
        if file in log_file.read(): 
            is_already_pred = True
            
    if not(is_already_pred): # If not, perform the prediction
        # Predict the values
        if os.stat(path).st_size<200*10**6:
          predict(path, preds_store_folder,  cnn, tn, scale = False,\
              is_ground_truth = False)

          # Write in the logs that this file is already predicted
          with open(log_path, "a") as log_file:
              log_file.write(file + '\n')

        step_time = time()
        average_pred_time = (step_time - start_time) / (idx + 1)
        remaining_time = average_pred_time * (nb_files_to_pred - idx - 1)
        print('Average per file pred time', average_pred_time, idx, 'files already predicted')
        print('Remaining time before end of pred', remaining_time)
          
    else:
        print(file, 'already predicted')
# Out:
# Currently predicting Labelled_Pulse5_2021-03-03 00h11.parq 0
# Labelled_Pulse5_2021-03-03 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-25 20h11.parq 1
# Labelled_Pulse5_2021-02-25 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-15 00h11.parq 2
# Labelled_Pulse5_2021-01-15 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-22 10h11.parq 3
# Labelled_Pulse5_2021-01-22 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-21 20h11.parq 4
# Labelled_Pulse5_2021-02-21 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-24 22h11.parq 5
# Labelled_Pulse5_2021-02-24 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-15 08h11.parq 6
# Labelled_Pulse5_2021-02-15 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-27 16h11.parq 7
# Labelled_Pulse5_2021-02-27 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-14 12h11.parq 8
# Labelled_Pulse5_2021-02-14 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-11 22h11.parq 9
# Labelled_Pulse5_2021-02-11 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-18 12h11.parq 10
# Labelled_Pulse5_2021-02-18 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-13 00h11.parq 11
# Labelled_Pulse5_2021-02-13 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-20 04h11.parq 12
# Labelled_Pulse5_2021-02-20 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-21 18h11.parq 13
# Labelled_Pulse5_2021-01-21 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-02 04h11.parq 14
# Labelled_Pulse5_2021-03-02 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-01 06h11.parq 15
# Labelled_Pulse5_2021-03-01 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-05 18h11.parq 16
# Labelled_Pulse5_2021-02-05 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-09 11h38.parq 17
# Labelled_Pulse5_2021-01-09 11h38.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-08 02h11.parq 18
# Labelled_Pulse5_2021-02-08 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-17 14h11.parq 19
# Labelled_Pulse5_2021-02-17 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-06 22h11.parq 20
# Labelled_Pulse5_2021-02-06 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-08 08h11.parq 21
# Labelled_Pulse5_2021-02-08 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-15 18h11.parq 22
# Labelled_Pulse5_2021-01-15 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-04 12h11.parq 23
# Labelled_Pulse5_2021-02-04 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-05 12h11.parq 24
# Labelled_Pulse5_2021-02-05 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-08 16h11.parq 25
# Labelled_Pulse5_2021-01-08 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-13 22h11.parq 26
# Labelled_Pulse5_2021-02-13 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-23 06h11.parq 27
# Labelled_Pulse5_2021-01-23 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-21 02h11.parq 28
# Labelled_Pulse5_2021-02-21 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-21 04h11.parq 29
# Labelled_Pulse5_2021-02-21 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-06 06h11.parq 30
# Labelled_Pulse5_2021-02-06 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-03 04h11.parq 31
# Labelled_Pulse5_2021-02-03 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-21 04h11.parq 32
# Labelled_Pulse5_2021-01-21 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-05 02h11.parq 33
# Labelled_Pulse5_2021-02-05 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-22 06h11.parq 34
# Labelled_Pulse5_2021-02-22 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-27 00h11.parq 35
# Labelled_Pulse5_2021-01-27 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-28 12h11.parq 36
# Labelled_Pulse5_2021-01-28 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-22 20h11.parq 37
# Labelled_Pulse5_2021-01-22 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-27 12h11.parq 38
# Labelled_Pulse5_2021-02-27 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-23 12h11.parq 39
# Labelled_Pulse5_2021-01-23 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-02 00h11.parq 40
# Labelled_Pulse5_2021-03-02 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-03 06h11.parq 41
# Labelled_Pulse5_2021-03-03 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-14 18h11.parq 42
# Labelled_Pulse5_2021-01-14 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-03 10h11.parq 43
# Labelled_Pulse5_2021-02-03 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-08 14h11.parq 44
# Labelled_Pulse5_2021-01-08 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-22 04h11.parq 45
# Labelled_Pulse5_2021-02-22 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-28 20h11.parq 46
# Labelled_Pulse5_2021-01-28 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-25 12h11.parq 47
# Labelled_Pulse5_2021-02-25 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-25 08h11.parq 48
# Labelled_Pulse5_2021-02-25 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-08 10h11.parq 49
# Labelled_Pulse5_2021-02-08 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-04 02h11.parq 50
# Labelled_Pulse5_2021-02-04 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-22 18h11.parq 51
# Labelled_Pulse5_2021-01-22 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-03 08h11.parq 52
# Labelled_Pulse5_2021-02-03 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-21 14h11.parq 53
# Labelled_Pulse5_2021-02-21 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-14 22h11.parq 54
# Labelled_Pulse5_2021-01-14 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-02 08h11.parq 55
# Labelled_Pulse5_2021-02-02 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-14 14h11.parq 56
# Labelled_Pulse5_2021-02-14 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-13 02h11.parq 57
# Labelled_Pulse5_2021-02-13 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-24 06h11.parq 58
# Labelled_Pulse5_2021-02-24 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-24 02h11.parq 59
# Labelled_Pulse5_2021-01-24 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-20 22h11.parq 60
# Labelled_Pulse5_2021-01-20 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-26 10h11.parq 61
# Labelled_Pulse5_2021-01-26 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-11 20h11.parq 62
# Labelled_Pulse5_2021-02-11 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-03 18h11.parq 63
# Labelled_Pulse5_2021-02-03 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-17 22h11.parq 64
# Labelled_Pulse5_2021-02-17 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-08 04h11.parq 65
# Labelled_Pulse5_2021-02-08 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-16 06h11.parq 66
# Labelled_Pulse5_2021-01-16 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-21 10h11.parq 67
# Labelled_Pulse5_2021-02-21 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-22 02h11.parq 68
# Labelled_Pulse5_2021-01-22 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-04 06h11.parq 69
# Labelled_Pulse5_2021-03-04 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-21 00h11.parq 70
# Labelled_Pulse5_2021-01-21 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-24 12h11.parq 71
# Labelled_Pulse5_2021-02-24 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-26 16h11.parq 72
# Labelled_Pulse5_2021-01-26 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-19 06h11.parq 73
# Labelled_Pulse5_2021-01-19 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-17 10h11.parq 74
# Labelled_Pulse5_2021-02-17 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-17 22h11.parq 75
# Labelled_Pulse5_2021-01-17 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-07 02h11.parq 76
# Labelled_Pulse5_2021-02-07 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-25 04h11.parq 77
# Labelled_Pulse5_2021-02-25 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-05 08h11.parq 78
# Labelled_Pulse5_2021-02-05 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-17 04h11.parq 79
# Labelled_Pulse5_2021-01-17 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-18 18h11.parq 80
# Labelled_Pulse5_2021-02-18 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-02 20h11.parq 81
# Labelled_Pulse5_2021-03-02 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-25 12h11.parq 82
# Labelled_Pulse5_2021-01-25 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-19 04h11.parq 83
# Labelled_Pulse5_2021-01-19 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-22 04h11.parq 84
# Labelled_Pulse5_2021-01-22 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-04 14h11.parq 85
# Labelled_Pulse5_2021-03-04 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-16 20h11.parq 86
# Labelled_Pulse5_2021-01-16 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-07 22h11.parq 87
# Labelled_Pulse5_2021-02-07 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-29 04h11.parq 88
# Labelled_Pulse5_2021-01-29 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-12 00h11.parq 89
# Labelled_Pulse5_2021-02-12 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-14 06h11.parq 90
# Labelled_Pulse5_2021-02-14 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-02 18h11.parq 91
# Labelled_Pulse5_2021-02-02 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-13 16h11.parq 92
# Average per file pred time 0.004641907189482002 92 files already predicted
# Remaining time before end of pred 0.9190976235174364
# Currently predicting Labelled_Pulse5_2021-01-25 04h11.parq 93
# Labelled_Pulse5_2021-01-25 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-16 14h11.parq 94
# Labelled_Pulse5_2021-01-16 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-28 00h11.parq 95
# Labelled_Pulse5_2021-01-28 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-09 02h11.parq 96
# Labelled_Pulse5_2021-01-09 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-18 22h11.parq 97
# Labelled_Pulse5_2021-02-18 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-07 18h11.parq 98
# Labelled_Pulse5_2021-02-07 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-16 04h11.parq 99
# Labelled_Pulse5_2021-02-16 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-10 00h11.parq 100
# Labelled_Pulse5_2021-02-10 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-08 20h11.parq 101
# Labelled_Pulse5_2021-01-08 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-19 12h11.parq 102
# Average per file pred time 0.21842101939673564 102 files already predicted
# Remaining time before end of pred 41.0631516465863
# Currently predicting Labelled_Pulse5_2021-02-12 10h11.parq 103
# Labelled_Pulse5_2021-02-12 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-01 04h11.parq 104
# Labelled_Pulse5_2021-03-01 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-25 20h11.parq 105
# Labelled_Pulse5_2021-01-25 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-21 22h11.parq 106
# Labelled_Pulse5_2021-01-21 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-14 00h11.parq 107
# Average per file pred time 0.2084391293702302 107 files already predicted
# Remaining time before end of pred 38.14436067475213
# Currently predicting Labelled_Pulse5_2021-01-28 14h11.parq 108
# Labelled_Pulse5_2021-01-28 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-15 06h11.parq 109
# Labelled_Pulse5_2021-01-15 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-25 14h11.parq 110
# Labelled_Pulse5_2021-02-25 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-17 10h11.parq 111
# Labelled_Pulse5_2021-01-17 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-21 02h11.parq 112
# Labelled_Pulse5_2021-01-21 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-18 00h11.parq 113
# Average per file pred time 0.40537262799447044 113 files already predicted
# Remaining time before end of pred 71.75095515502127
# Currently predicting Labelled_Pulse5_2021-02-24 02h11.parq 114
# Average per file pred time 0.597189065684443 114 files already predicted
# Remaining time before end of pred 105.10527556046196
# Currently predicting Labelled_Pulse5_2021-01-14 04h11.parq 115
# Average per file pred time 0.5920842536564531 115 files already predicted
# Remaining time before end of pred 103.61474438987929
# Currently predicting Labelled_Pulse5_2021-02-20 22h11.parq 116
# Labelled_Pulse5_2021-02-20 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-05 06h11.parq 117
# Labelled_Pulse5_2021-02-05 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-12 22h11.parq 118
# Labelled_Pulse5_2021-02-12 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-15 22h11.parq 119
# Labelled_Pulse5_2021-01-15 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-22 20h11.parq 120
# Labelled_Pulse5_2021-02-22 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-06 14h11.parq 121
# Labelled_Pulse5_2021-03-06 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-27 04h11.parq 122
# Labelled_Pulse5_2021-02-27 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-16 04h11.parq 123
# Labelled_Pulse5_2021-01-16 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-06 16h11.parq 124
# Average per file pred time 0.7736220893859863 124 files already predicted
# Remaining time before end of pred 128.42126683807373
# Currently predicting Labelled_Pulse5_2021-02-04 06h11.parq 125
# Labelled_Pulse5_2021-02-04 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-18 06h11.parq 126
# Average per file pred time 1.035231256109523 126 files already predicted
# Remaining time before end of pred 169.77792600196176
# Currently predicting Labelled_Pulse5_2021-02-01 20h11.parq 127
# Labelled_Pulse5_2021-02-01 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-06 00h11.parq 128
# Labelled_Pulse5_2021-03-06 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-20 06h11.parq 129
# Labelled_Pulse5_2021-02-20 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-17 16h11.parq 130
# Labelled_Pulse5_2021-02-17 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-04 22h11.parq 131
# Labelled_Pulse5_2021-02-04 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-24 16h11.parq 132
# Labelled_Pulse5_2021-01-24 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-23 18h11.parq 133
# Labelled_Pulse5_2021-01-23 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-14 10h11.parq 134
# Labelled_Pulse5_2021-01-14 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-15 12h11.parq 135
# Labelled_Pulse5_2021-01-15 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-23 16h11.parq 136
# Labelled_Pulse5_2021-01-23 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-19 08h11.parq 137
# Labelled_Pulse5_2021-01-19 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-09 12h43.parq 138
# Labelled_Pulse5_2021-01-09 12h43.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-25 22h11.parq 139
# Labelled_Pulse5_2021-01-25 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-18 16h11.parq 140
# Labelled_Pulse5_2021-01-18 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-16 10h11.parq 141
# Labelled_Pulse5_2021-02-16 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-05 20h11.parq 142
# Labelled_Pulse5_2021-03-05 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-24 04h11.parq 143
# Labelled_Pulse5_2021-02-24 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-28 02h11.parq 144
# Average per file pred time 1.2245937380297431 144 files already predicted
# Remaining time before end of pred 178.7906857523425
# Currently predicting Labelled_Pulse5_2021-03-02 08h11.parq 145
# Labelled_Pulse5_2021-03-02 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-17 04h11.parq 146
# Labelled_Pulse5_2021-02-17 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-15 14h11.parq 147
# Labelled_Pulse5_2021-02-15 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-02 18h11.parq 148
# Labelled_Pulse5_2021-03-02 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-03 06h11.parq 149
# Labelled_Pulse5_2021-02-03 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-16 12h11.parq 150
# Labelled_Pulse5_2021-02-16 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-30 04h11.parq 151
# Labelled_Pulse5_2021-01-30 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-19 00h11.parq 152
# Labelled_Pulse5_2021-01-19 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-20 16h11.parq 153
# Labelled_Pulse5_2021-02-20 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-04 18h11.parq 154
# Labelled_Pulse5_2021-02-04 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-13 10h11.parq 155
# Labelled_Pulse5_2021-02-13 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-12 12h11.parq 156
# Labelled_Pulse5_2021-02-12 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-12 06h11.parq 157
# Labelled_Pulse5_2021-02-12 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-01 22h11.parq 158
# Labelled_Pulse5_2021-02-01 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-22 22h11.parq 159
# Labelled_Pulse5_2021-01-22 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-30 02h11.parq 160
# Average per file pred time 1.4680101205103147 160 files already predicted
# Remaining time before end of pred 190.8413156663409
# Currently predicting Labelled_Pulse5_2021-02-23 12h11.parq 161
# Average per file pred time 1.5542041122177501 161 files already predicted
# Remaining time before end of pred 200.49233047608976
# Currently predicting Labelled_Pulse5_2021-01-27 02h11.parq 162
# Labelled_Pulse5_2021-01-27 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-08 18h11.parq 163
# Labelled_Pulse5_2021-01-08 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-05 16h11.parq 164
# Labelled_Pulse5_2021-02-05 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-10 08h11.parq 165
# Labelled_Pulse5_2021-02-10 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-28 22h11.parq 166
# Labelled_Pulse5_2021-02-28 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-22 08h11.parq 167
# Labelled_Pulse5_2021-02-22 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-23 22h11.parq 168
# Labelled_Pulse5_2021-02-23 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-19 22h11.parq 169
# Labelled_Pulse5_2021-02-19 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-17 08h11.parq 170
# Labelled_Pulse5_2021-02-17 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-03 18h11.parq 171
# Labelled_Pulse5_2021-03-03 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-13 04h11.parq 172
# Labelled_Pulse5_2021-02-13 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-07 04h11.parq 173
# Average per file pred time 1.669303469274236 173 files already predicted
# Remaining time before end of pred 195.3085059050856
# Currently predicting Labelled_Pulse5_2021-03-05 00h11.parq 174
# Average per file pred time 1.6978261607033867 174 files already predicted
# Remaining time before end of pred 196.94783464159286
# Currently predicting Labelled_Pulse5_2021-02-16 08h11.parq 175
# Average per file pred time 1.883241053331982 175 files already predicted
# Remaining time before end of pred 216.57272113317794
# Currently predicting Labelled_Pulse5_2021-03-01 22h11.parq 176
# Labelled_Pulse5_2021-03-01 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-28 18h11.parq 177
# Labelled_Pulse5_2021-01-28 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-25 00h11.parq 178
# Labelled_Pulse5_2021-01-25 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-19 16h11.parq 179
# Labelled_Pulse5_2021-02-19 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-27 18h11.parq 180
# Labelled_Pulse5_2021-01-27 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-17 06h11.parq 181
# Labelled_Pulse5_2021-02-17 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-19 08h11.parq 182
# Average per file pred time 2.1314581378561552 182 files already predicted
# Remaining time before end of pred 230.19747888846476
# Currently predicting Labelled_Pulse5_2021-02-15 00h11.parq 183
# Labelled_Pulse5_2021-02-15 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-15 12h11.parq 184
# Labelled_Pulse5_2021-02-15 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-03 14h11.parq 185
# Labelled_Pulse5_2021-03-03 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-11 16h11.parq 186
# Labelled_Pulse5_2021-02-11 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-17 18h11.parq 187
# Labelled_Pulse5_2021-01-17 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-16 18h11.parq 188
# Labelled_Pulse5_2021-02-16 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-05 22h11.parq 189
# Labelled_Pulse5_2021-02-05 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-13 12h12.parq 190
# Average per file pred time 2.0422998847761704 190 files already predicted
# Remaining time before end of pred 204.22998847761704
# Currently predicting Labelled_Pulse5_2021-03-06 08h11.parq 191
# Labelled_Pulse5_2021-03-06 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-21 08h11.parq 192
# Labelled_Pulse5_2021-02-21 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-26 02h11.parq 193
# Labelled_Pulse5_2021-01-26 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-24 14h11.parq 194
# Labelled_Pulse5_2021-02-24 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-23 06h11.parq 195
# Labelled_Pulse5_2021-02-23 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-20 00h11.parq 196
# Labelled_Pulse5_2021-02-20 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-27 08h11.parq 197
# Labelled_Pulse5_2021-02-27 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-07 08h11.parq 198
# Labelled_Pulse5_2021-02-07 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-10 20h11.parq 199
# Labelled_Pulse5_2021-02-10 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-14 00h11.parq 200
# Labelled_Pulse5_2021-02-14 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-09 18h11.parq 201
# Labelled_Pulse5_2021-02-09 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-11 02h11.parq 202
# Labelled_Pulse5_2021-02-11 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-14 12h11.parq 203
# Labelled_Pulse5_2021-01-14 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-14 16h11.parq 204
# Labelled_Pulse5_2021-02-14 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-25 18h11.parq 205
# Labelled_Pulse5_2021-02-25 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-10 14h11.parq 206
# Labelled_Pulse5_2021-02-10 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-16 16h11.parq 207
# Labelled_Pulse5_2021-01-16 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-19 06h11.parq 208
# Labelled_Pulse5_2021-02-19 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-21 08h11.parq 209
# Labelled_Pulse5_2021-01-21 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-02 02h11.parq 210
# Labelled_Pulse5_2021-03-02 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-21 20h11.parq 211
# Labelled_Pulse5_2021-01-21 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-13 22h11.parq 212
# Average per file pred time 1.831588065680204 212 files already predicted
# Remaining time before end of pred 142.8638691230559
# Currently predicting Labelled_Pulse5_2021-01-18 14h11.parq 213
# Labelled_Pulse5_2021-01-18 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-26 18h11.parq 214
# Labelled_Pulse5_2021-01-26 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-11 00h11.parq 215
# Labelled_Pulse5_2021-02-11 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-22 18h11.parq 216
# Labelled_Pulse5_2021-02-22 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-19 02h11.parq 217
# Labelled_Pulse5_2021-01-19 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-14 22h11.parq 218
# Labelled_Pulse5_2021-02-14 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-05 08h11.parq 219
# Labelled_Pulse5_2021-03-05 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-15 08h11.parq 220
# Labelled_Pulse5_2021-01-15 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-01 02h11.parq 221
# Labelled_Pulse5_2021-03-01 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-27 12h11.parq 222
# Labelled_Pulse5_2021-01-27 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-09 16h11.parq 223
# Labelled_Pulse5_2021-02-09 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-07 00h11.parq 224
# Labelled_Pulse5_2021-02-07 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-08 11h35.parq 225
# Labelled_Pulse5_2021-01-08 11h35.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-10 04h11.parq 226
# Labelled_Pulse5_2021-02-10 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-24 06h11.parq 227
# Labelled_Pulse5_2021-01-24 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-09 06h11.parq 228
# Labelled_Pulse5_2021-01-09 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-08 00h11.parq 229
# Labelled_Pulse5_2021-02-08 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-02 14h11.parq 230
# Labelled_Pulse5_2021-02-02 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-23 20h11.parq 231
# Labelled_Pulse5_2021-02-23 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-26 12h11.parq 232
# Labelled_Pulse5_2021-02-26 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-03 10h11.parq 233
# Labelled_Pulse5_2021-03-03 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-16 02h11.parq 234
# Labelled_Pulse5_2021-01-16 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-15 18h11.parq 235
# Labelled_Pulse5_2021-02-15 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-02 16h11.parq 236
# Labelled_Pulse5_2021-03-02 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-02 06h11.parq 237
# Labelled_Pulse5_2021-03-02 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-06 18h11.parq 238
# Labelled_Pulse5_2021-03-06 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-20 20h11.parq 239
# Labelled_Pulse5_2021-01-20 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-06 04h11.parq 240
# Labelled_Pulse5_2021-03-06 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-24 20h11.parq 241
# Labelled_Pulse5_2021-02-24 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-05 06h11.parq 242
# Labelled_Pulse5_2021-03-05 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-11 12h11.parq 243
# Labelled_Pulse5_2021-02-11 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-12 20h11.parq 244
# Labelled_Pulse5_2021-02-12 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-27 00h11.parq 245
# Labelled_Pulse5_2021-02-27 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-06 12h11.parq 246
# Labelled_Pulse5_2021-02-06 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-22 00h11.parq 247
# Labelled_Pulse5_2021-01-22 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-13 14h11.parq 248
# Labelled_Pulse5_2021-02-13 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-06 02h11.parq 249
# Labelled_Pulse5_2021-02-06 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-27 10h11.parq 250
# Labelled_Pulse5_2021-02-27 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-13 06h11.parq 251
# Labelled_Pulse5_2021-02-13 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-18 00h11.parq 252
# Labelled_Pulse5_2021-01-18 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-17 00h11.parq 253
# Labelled_Pulse5_2021-01-17 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-28 10h11.parq 254
# Labelled_Pulse5_2021-01-28 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-03 20h11.parq 255
# Labelled_Pulse5_2021-03-03 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-26 20h11.parq 256
# Labelled_Pulse5_2021-01-26 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-26 16h11.parq 257
# Labelled_Pulse5_2021-02-26 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-19 04h11.parq 258
# Labelled_Pulse5_2021-02-19 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-24 18h11.parq 259
# Labelled_Pulse5_2021-02-24 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-23 00h11.parq 260
# Labelled_Pulse5_2021-01-23 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-22 10h11.parq 261
# Labelled_Pulse5_2021-02-22 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-24 18h11.parq 262
# Labelled_Pulse5_2021-01-24 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-01 12h11.parq 263
# Labelled_Pulse5_2021-03-01 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-01 08h11.parq 264
# Labelled_Pulse5_2021-03-01 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-16 20h11.parq 265
# Labelled_Pulse5_2021-02-16 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-02 00h11.parq 266
# Labelled_Pulse5_2021-02-02 00h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-24 08h11.parq 267
# Labelled_Pulse5_2021-01-24 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-23 02h11.parq 268
# Labelled_Pulse5_2021-02-23 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-22 14h11.parq 269
# Labelled_Pulse5_2021-02-22 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-18 10h11.parq 270
# Labelled_Pulse5_2021-02-18 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-27 14h11.parq 271
# Labelled_Pulse5_2021-01-27 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-24 12h11.parq 272
# Labelled_Pulse5_2021-01-24 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-17 12h11.parq 273
# Labelled_Pulse5_2021-02-17 12h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-24 22h11.parq 274
# Labelled_Pulse5_2021-01-24 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-23 10h11.parq 275
# Labelled_Pulse5_2021-01-23 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-15 04h11.parq 276
# Labelled_Pulse5_2021-01-15 04h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-29 16h11.parq 277
# Labelled_Pulse5_2021-01-29 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-18 18h11.parq 278
# Labelled_Pulse5_2021-01-18 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-15 02h11.parq 279
# Labelled_Pulse5_2021-02-15 02h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-05 20h11.parq 280
# Labelled_Pulse5_2021-02-05 20h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-04 08h11.parq 281
# Labelled_Pulse5_2021-02-04 08h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-04 22h11.parq 282
# Labelled_Pulse5_2021-03-04 22h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-21 18h11.parq 283
# Labelled_Pulse5_2021-02-21 18h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-02-05 10h11.parq 284
# Labelled_Pulse5_2021-02-05 10h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-18 06h11.parq 285
# Labelled_Pulse5_2021-01-18 06h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-19 14h11.parq 286
# Labelled_Pulse5_2021-01-19 14h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-20 14h12.parq 287
# Labelled_Pulse5_2021-01-20 14h12.parq already predicted
# Currently predicting Labelled_Pulse5_2021-01-25 08h11.parq 288
# Average per file pred time 1.5535071902621576 288 files already predicted
# Remaining time before end of pred 3.107014380524315
# Currently predicting Labelled_Pulse5_2021-01-17 16h11.parq 289
# Labelled_Pulse5_2021-01-17 16h11.parq already predicted
# Currently predicting Labelled_Pulse5_2021-03-05 10h11.parq 290
# Average per file pred time 1.5634033606224453 290 files already predicted
# Remaining time before end of pred 0.0
